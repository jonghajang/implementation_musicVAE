# %% [markdown]
# ## musicVAE를 이용해 4마디의 드럼비트를 생성하는 과제입니다.
#
# Midi 데이터와 musicVAE에 대한 이해와 구현을 동시에 해야하기 때문에
# 다양한 시도와 입출력을 보기위해 Jupyter Notebook 형태로 제출하는 점 양해 부탁드립니다.

# %%
import os
import wandb
from magenta.common import merge_hparams
from magenta.contrib import training as contrib_training
from magenta.models.music_vae.music_vae_train import run
from magenta.models.music_vae import MusicVAE, lstm_models, configs
from magenta.models.music_vae import data
from magenta.models.music_vae.trained_model import TrainedModel
import collections
import tensorflow.compat.v1 as tf
import tf_slim

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# wandb.login(key='')
# wandb.init(project="poza", reinit=True)

# %% [markdown]
# ## 세가지 모델구조를 테스트 했습니다.
# ***Config를 살펴본 결과 Drum 비트에 맞는 config, Groovae라는 이름의 config(GrooveConverter에서 Drum 피치를 select)를 사용했습니다.***
#
# ***추가로 논문에서 제시하는 Hierarchical 디코더 구조를 적용하고자 했습니다.***

# %%
class Config(collections.namedtuple('Config',
                                    ['model', 'hparams', 'note_sequence_augmenter', 'data_converter',
                                     'train_examples_path', 'eval_examples_path', 'tfds_name'])):
    def values(self):
        return self._asdict()

Config.__new__.__defaults__ = (None,) * len(Config._fields)

def update_config(config, update_dict):
    config_dict = config.values()
    config_dict.update(update_dict)
    return Config(**config_dict)

HParams = contrib_training.HParams

CONFIG_MAP = {}
CONFIG_MAP['groovae_4bar'] = Config(
    model=MusicVAE(lstm_models.BidirectionalLstmEncoder(),
                   lstm_models.GrooveLstmDecoder()),
    hparams=merge_hparams(
        lstm_models.get_default_hparams(),
        HParams(
            batch_size=512,
            max_seq_len=16 * 4,  # 4 bars w/ 16 steps per bar
            z_size=256,
            enc_rnn_size=[512],
            dec_rnn_size=[256, 256],
            max_beta=0.2,
            free_bits=48,
            dropout_keep_prob=0.3,
        )),
    note_sequence_augmenter=None,
    data_converter=data.GrooveConverter(
        split_bars=4, steps_per_quarter=4, quarters_per_bar=4,
        max_tensors_per_notesequence=20,
        pitch_classes=data.ROLAND_DRUM_PITCH_CLASSES,
        inference_pitch_classes=data.REDUCED_DRUM_PITCH_CLASSES),
    # 미리 파싱한 커스텀 데이터로 변경
    train_examples_path='./data/groovae_4bar.tfrecord-00000-of-00001',
    eval_examples_path='./data/groove_eval/eval_music.tfrecord'
)

CONFIG_MAP['cat-drums_2bar_big'] = Config(
    model=MusicVAE(lstm_models.BidirectionalLstmEncoder(),
                   lstm_models.CategoricalLstmDecoder()),
    hparams=merge_hparams(
        lstm_models.get_default_hparams(),
        HParams(
            batch_size=512,
            max_seq_len=64,  # 원래 2bars를 4bars로 변환했습니다. 4 bars w/ 16 steps per bar
            z_size=512,
            enc_rnn_size=[2048],
            dec_rnn_size=[2048, 2048, 2048],
            free_bits=48,
            max_beta=0.2,
            sampling_schedule='inverse_sigmoid',
            sampling_rate=1000,
        )),
    note_sequence_augmenter=None,
    data_converter=data.DrumsConverter(
        # max_bars=100,  # 앞서 pre-processing 과정을 거쳤기 때문에 주석처리
        slice_bars=4,
        steps_per_quarter=4,
        roll_input=False),
    # change to custom data
    train_examples_path='./data/groovae_4bar.tfrecord-00000-of-00001',
    eval_examples_path='./data/groove_eval/eval_music.tfrecord',
)

CONFIG_MAP['groovae_4bar_hier'] = Config(
    model=MusicVAE(lstm_models.BidirectionalLstmEncoder(),
                   lstm_models.HierarchicalLstmDecoder(
                       lstm_models.GrooveLstmDecoder(),
                       level_lengths=[16, 4])),
    hparams=merge_hparams(
        lstm_models.get_default_hparams(),
        HParams(
            batch_size=512,
            max_seq_len=16 * 4,  # 4 bars w/ 16 steps per bar
            z_size=256,
            enc_rnn_size=[512],
            dec_rnn_size=[256, 256],
            max_beta=0.2,
            free_bits=48,
            dropout_keep_prob=0.3,
        )),
    note_sequence_augmenter=None,
    data_converter=data.GrooveConverter(
        split_bars=4, steps_per_quarter=4, quarters_per_bar=4,
        max_tensors_per_notesequence=20,
        pitch_classes=data.ROLAND_DRUM_PITCH_CLASSES,
        inference_pitch_classes=data.REDUCED_DRUM_PITCH_CLASSES),
    # change to custom data
    train_examples_path='./data/groovae_4bar.tfrecord-00000-of-00001',
    eval_examples_path='./data/groove_eval/eval_music.tfrecord'
)

# %%
def _get_input_tensors(dataset, config):
    batch_size = config.hparams.batch_size
    iterator = tf.data.make_one_shot_iterator(dataset)
    (input_sequence, output_sequence, control_sequence,
    sequence_length) = iterator.get_next()
    input_sequence.set_shape(
    [batch_size, None, config.data_converter.input_depth])
    output_sequence.set_shape(
    [batch_size, None, config.data_converter.output_depth])
    
    if not config.data_converter.control_depth:
        control_sequence = None
    
    else:
        control_sequence.set_shape(
            [batch_size, None, config.data_converter.control_depth])
        sequence_length.set_shape([batch_size] + sequence_length.shape[1:].as_list())
        
    return {
        'input_sequence': input_sequence,
        'output_sequence': output_sequence,
        'control_sequence': control_sequence,
        'sequence_length': sequence_length
    }

# %% [markdown]
# **training loss와 config를 기록하기 위해 W&B를 활용하고자 했습니다. 하지만 tensorflow 버전과 잘 맞지 않아 실패했습니다.**

# %%
def train(train_dir,
          config,
          dataset_fn,
          checkpoints_to_keep=5,
          keep_checkpoint_every_n_hours=1,
          num_steps=None,
          master='',
          num_sync_workers=0,
          num_ps_tasks=0,
          task=0):

    # train loop
    tf.gfile.MakeDirs(train_dir)
    is_chief = (task == 0)
    tf.disable_v2_behavior()
    with tf.Session() as sess:
        with tf.Graph().as_default():
            with tf.device(tf.train.replica_device_setter(num_ps_tasks, merge_devices=True)):
                model = config.model
                model.build(config.hparams, config.data_converter.output_depth, is_training=True)

                # optimizer
                optimizer = model.train(**_get_input_tensors(dataset_fn(), config))

                hooks = []

                if num_sync_workers:
                    optimizer = tf.train.SyncReplicasOptimizer(optimizer, num_sync_workers)
                    hooks.append(optimizer.make_session_run_hook(is_chief))

                grads, var_list = list(zip(*optimizer.compute_gradients(model.loss)))
                global_norm = tf.global_norm(grads)
                tf.summary.scalar('global_norm', global_norm)

                if config.hparams.clip_mode == 'value':
                    g = config.hparams.grad_clip
                    clipped_grads = [tf.clip_by_value(grad, -g, g) for grad in grads]
                elif config.hparams.clip_mode == 'global_norm':
                    clipped_grads = tf.cond(
                        global_norm < config.hparams.grad_norm_clip_to_zero,
                        lambda: tf.clip_by_global_norm(  # pylint:disable=g-long-lambda
                            grads, config.hparams.grad_clip, use_norm=global_norm)[0],
                        lambda: [tf.zeros(tf.shape(g)) for g in grads])
                else:
                    raise ValueError('Unknown clip_mode: {}'.format(config.hparams.clip_mode))

                train_op = optimizer.apply_gradients(
                    list(zip(clipped_grads, var_list)),
                    global_step=model.global_step,
                    name='train_step')

                # loss_value, _ = sess.run([model.loss, model.train_op])
                logging_dict = {'global_step': model.global_step, 'loss': model.loss}
                # wandb.log(logging_dict) # training loss를 기록하기 위해 W&B를 활용하고자 했습니다. tensorflow 버전과 잘 맞지않아 실패했습니다.
                hooks.append(tf.train.LoggingTensorHook(logging_dict, every_n_iter=100))

                if num_steps:
                    hooks.append(tf.train.StopAtStepHook(last_step=num_steps))

                scaffold = tf.train.Scaffold(
                    saver=tf.train.Saver(max_to_keep=checkpoints_to_keep,
                                         keep_checkpoint_every_n_hours=keep_checkpoint_every_n_hours))

                tf_slim.training.train(train_op=train_op,
                                       logdir=train_dir,
                                       scaffold=scaffold,
                                       hooks=hooks,
                                       save_checkpoint_secs=60,
                                       master=master,
                                       is_chief=is_chief)

# %%
# 평가를 위해 evaluate code를 따와서 모델 체크포인트 마다 따로 분리한 평가셋으로 평가하려고 했지만, 평가 결과가 기록되지 않아 
# validation set의 평가는 하지 못했습니다.

def evaluate(train_dir,
             eval_dir,
             config,
             dataset_fn,
             num_batches,
             master=''):
    """Evaluate the model repeatedly."""
    tf.gfile.MakeDirs(eval_dir)
    
    with tf.Graph().as_default():
        model = config.model
        model.build(config.hparams,
                    config.data_converter.output_depth,
                    is_training=False)

        eval_op = model.eval(
            **_get_input_tensors(dataset_fn(False).take(num_batches), config))

        hooks = [
            tf_slim.evaluation.StopAfterNEvalsHook(num_batches),
            tf_slim.evaluation.SummaryAtEndHook(eval_dir)
        ]
        tf_slim.evaluation.evaluate_repeatedly(
            train_dir,
            eval_ops=eval_op,
            hooks=hooks,
            eval_interval_secs=60,
            master=master)

# %% [markdown]
# ### TEST 1 : groovae_4bar Config

# %%
def run(config_map,
        tf_file_reader=tf.data.TFRecordDataset,
        file_reader=tf.python_io.tf_record_iterator):
    config = config_map
    train_dir = './model_checkpoint_groovae_4bar_test'
    # eval_dir = './model_checkpoint_groovae_4bar_eval'
    num_steps = 5000
    
    def dataset_fn():
        return data.get_dataset(
            config,
            tf_file_reader=tf_file_reader,
            is_training=True,
            cache_dataset=True)
        
    train(train_dir,
          config=config,
          dataset_fn=dataset_fn,
          num_steps=num_steps)

# %%
# step 5000

run(CONFIG_MAP['groovae_4bar'])

# %% [markdown]
# ### cat-drums_2bar_big
# ***이유를 찾지 못했지만 step이 0에서 증가되지 않아 테스트 불가했습니다***

# %%
def run(config_map,
        tf_file_reader=tf.data.TFRecordDataset,
        file_reader=tf.python_io.tf_record_iterator,
        is_training=True):
    config = config_map
    train_dir = './model_checkpoint_cat_drums_4bar_big'
    num_steps = 5000
    
    def dataset_fn():
        return data.get_dataset(
            config,
            tf_file_reader=tf_file_reader,
            is_training=True,
            cache_dataset=True)
    
    if is_training == True:
        train(
            train_dir,
            config=config,
            dataset_fn=dataset_fn,
            num_steps=num_steps)      
    
    else:
        print("EVAL")

# %%
# step 5000

run(CONFIG_MAP['cat-drums_2bar_big'])

# %% [markdown]
# ### groovae_4bar HierarchicalLstmDecoder added
# **musicVAE 논문에서 제안하는 핵심인 HIERARCHICAL한 디코더 구조를 적용했습니다.<br>**
# -속도적 측면에서 기존 Groove Decoder 대비 약 3배 정도 느린 학습속도를 보였습니다.
# <br> -하지만 training loss가 비슷한 step 대비 81.326515 -> 55.0133로 낮아진 경향을 보였습니다.

# %% [markdown]
# **추가적으로 Max Beta를 0.2 -> 0.1로 감소시켜 샘플의 다양성을 증가시킬 수 있게 학습되도록 유도했습니다. 동시에 free bits를 조금은 감소시켜 이 효과를 보정하려 했습니다.**

# %%
CONFIG_MAP['groovae_4bar_hier'] = Config(
    model=MusicVAE(lstm_models.BidirectionalLstmEncoder(),
                   lstm_models.HierarchicalLstmDecoder(
                       lstm_models.GrooveLstmDecoder(),
                       level_lengths=[16, 4])),
    hparams=merge_hparams(
        lstm_models.get_default_hparams(),
        HParams(
            batch_size=512,
            max_seq_len=16 * 4,  # 4 bars w/ 16 steps per bar
            z_size=256,
            enc_rnn_size=[512],
            dec_rnn_size=[256, 256],
            max_beta=0.1, # change for diversity
            free_bits=45, # change lower for trade off
            dropout_keep_prob=0.3,
        )),
    note_sequence_augmenter=None,
    data_converter=data.GrooveConverter(
        split_bars=4, steps_per_quarter=4, quarters_per_bar=4,
        max_tensors_per_notesequence=20,
        pitch_classes=data.ROLAND_DRUM_PITCH_CLASSES,
        inference_pitch_classes=data.REDUCED_DRUM_PITCH_CLASSES),
    # change to custom data
    train_examples_path='./data/groovae_4bar.tfrecord-00000-of-00001',
    eval_examples_path='./data/groove_eval/eval_music.tfrecord'
)

# %%
def run(config_map,
        tf_file_reader=tf.data.TFRecordDataset,
        file_reader=tf.python_io.tf_record_iterator):
    config = config_map
    train_dir = './model_checkpoint_groovae_4bar_hier_beta'
    num_steps = 5000
    
    def dataset_fn():
        return data.get_dataset(
            config,
            tf_file_reader=tf_file_reader,
            is_training=True,
            cache_dataset=True)
        
    train(train_dir,
          config=config,
          dataset_fn=dataset_fn,
          num_steps=num_steps)

# %%
# step 5000
# global_step = 4900, loss = 55.0133

run(CONFIG_MAP['groovae_4bar_hier'])
# Out:
# INFO:tensorflow:Building MusicVAE model with BidirectionalLstmEncoder, HierarchicalLstmDecoder, and hparams:
# {'max_seq_len': 64, 'z_size': 256, 'free_bits': 45, 'max_beta': 0.1, 'beta_rate': 0.0, 'batch_size': 512, 'grad_clip': 1.0, 'clip_mode': 'global_norm', 'grad_norm_clip_to_zero': 10000, 'learning_rate': 0.001, 'decay_rate': 0.9999, 'min_learning_rate': 1e-05, 'conditional': True, 'dec_rnn_size': [256, 256], 'enc_rnn_size': [512], 'dropout_keep_prob': 0.3, 'sampling_schedule': 'constant', 'sampling_rate': 0.0, 'use_cudnn': False, 'residual_encoder': False, 'residual_decoder': False, 'control_preprocessing_rnn_size': [256]}
# INFO:tensorflow:
# Encoder Cells (bidirectional):
#   units: [512]
#
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# INFO:tensorflow:
# Hierarchical Decoder:
#   input length: 64
#   level output lengths: [16, 4]
#
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# INFO:tensorflow:
# Decoder Cells:
#   units: [256, 256]
#
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# INFO:tensorflow:Reading examples from file: ./data/groovae_4bar.tfrecord-00000-of-00001
# 2023-03-30 19:15:04.161939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46721 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:4f:00.0, compute capability: 8.6
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2023-03-30 19:16:35.101967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46721 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:4f:00.0, compute capability: 8.6
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-0.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-0.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-0.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# 2023-03-30 19:19:21.356416: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 1442 of 5120
# 2023-03-30 19:19:30.066230: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 2791 of 5120
# 2023-03-30 19:19:40.058544: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 4132 of 5120
# 2023-03-30 19:19:46.189211: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1...
# INFO:tensorflow:Saving checkpoints for 1 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1...
# INFO:tensorflow:global_step = 0, loss = 544.5548
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2...
# INFO:tensorflow:Saving checkpoints for 2 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 79...
# INFO:tensorflow:Saving checkpoints for 79 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-79.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-79.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-79.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 79...
# INFO:tensorflow:global_step/sec: 0.654189
# INFO:tensorflow:global_step = 100, loss = 201.46837 (143.934 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 149...
# INFO:tensorflow:Saving checkpoints for 149 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-149.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-149.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-149.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 149...
# INFO:tensorflow:global_step/sec: 1.20443
# INFO:tensorflow:global_step = 200, loss = 200.21225 (83.026 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 218...
# INFO:tensorflow:Saving checkpoints for 218 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-218.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-218.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-218.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 218...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 286...
# INFO:tensorflow:Saving checkpoints for 286 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-286.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-286.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-286.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 286...
# INFO:tensorflow:global_step/sec: 1.06709
# INFO:tensorflow:global_step = 300, loss = 185.94803 (93.710 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 356...
# INFO:tensorflow:Saving checkpoints for 356 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-356.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-356.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-356.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 356...
# INFO:tensorflow:global_step/sec: 1.20121
# INFO:tensorflow:global_step = 400, loss = 175.50536 (83.252 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 424...
# INFO:tensorflow:Saving checkpoints for 424 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-424.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-424.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-424.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 424...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 491...
# INFO:tensorflow:Saving checkpoints for 491 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-491.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-491.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-491.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 491...
# INFO:tensorflow:global_step/sec: 1.05863
# INFO:tensorflow:global_step = 500, loss = 168.4307 (94.458 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 560...
# INFO:tensorflow:Saving checkpoints for 560 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-560.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-560.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-560.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 560...
# INFO:tensorflow:global_step/sec: 1.20685
# INFO:tensorflow:global_step = 600, loss = 160.54832 (82.861 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 629...
# INFO:tensorflow:Saving checkpoints for 629 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-629.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-629.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-629.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 629...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 697...
# INFO:tensorflow:Saving checkpoints for 697 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-697.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-697.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-697.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 697...
# INFO:tensorflow:global_step/sec: 1.06457
# INFO:tensorflow:global_step = 700, loss = 148.36531 (93.940 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 765...
# INFO:tensorflow:Saving checkpoints for 765 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-765.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-765.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-765.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 765...
# INFO:tensorflow:global_step/sec: 1.2028
# INFO:tensorflow:global_step = 800, loss = 145.95378 (83.133 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 834...
# INFO:tensorflow:Saving checkpoints for 834 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-834.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-834.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-834.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 834...
# INFO:tensorflow:global_step/sec: 1.28412
# INFO:tensorflow:global_step = 900, loss = 136.44089 (77.876 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 910...
# INFO:tensorflow:Saving checkpoints for 910 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-910.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-910.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-910.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 910...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 979...
# INFO:tensorflow:Saving checkpoints for 979 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-979.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-979.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-979.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 979...
# INFO:tensorflow:global_step/sec: 1.06956
# INFO:tensorflow:global_step = 1000, loss = 134.58087 (93.495 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1047...
# INFO:tensorflow:Saving checkpoints for 1047 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1047.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1047.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1047.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1047...
# INFO:tensorflow:global_step/sec: 1.21455
# INFO:tensorflow:global_step = 1100, loss = 128.61113 (82.335 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1117...
# INFO:tensorflow:Saving checkpoints for 1117 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1117.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1117.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1117.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1117...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1185...
# INFO:tensorflow:Saving checkpoints for 1185 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1185.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1185.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1185.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1185...
# INFO:tensorflow:global_step/sec: 1.06671
# INFO:tensorflow:global_step = 1200, loss = 122.19955 (93.747 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1253...
# INFO:tensorflow:Saving checkpoints for 1253 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1253.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1253.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1253.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1253...
# INFO:tensorflow:global_step/sec: 1.19236
# INFO:tensorflow:global_step = 1300, loss = 119.34178 (83.869 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1322...
# INFO:tensorflow:Saving checkpoints for 1322 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1322.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1322.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1322.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1322...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1389...
# INFO:tensorflow:Saving checkpoints for 1389 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1389.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1389.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1389.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1389...
# INFO:tensorflow:global_step/sec: 1.04784
# INFO:tensorflow:global_step = 1400, loss = 114.7958 (95.431 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1456...
# INFO:tensorflow:Saving checkpoints for 1456 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1456.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1456.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1456.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1456...
# INFO:tensorflow:global_step/sec: 1.20552
# INFO:tensorflow:global_step = 1500, loss = 113.05686 (82.953 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1526...
# INFO:tensorflow:Saving checkpoints for 1526 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1526.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1526.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1526.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1526...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1594...
# INFO:tensorflow:Saving checkpoints for 1594 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1594.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1594.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1594.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1594...
# INFO:tensorflow:global_step/sec: 1.07127
# INFO:tensorflow:global_step = 1600, loss = 110.711586 (93.346 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1664...
# INFO:tensorflow:Saving checkpoints for 1664 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1664.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1664.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1664.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1664...
# INFO:tensorflow:global_step/sec: 1.22698
# INFO:tensorflow:global_step = 1700, loss = 105.03332 (81.502 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1734...
# INFO:tensorflow:Saving checkpoints for 1734 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1734.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1734.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1734.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1734...
# INFO:tensorflow:global_step/sec: 1.19337
# INFO:tensorflow:global_step = 1800, loss = 102.207115 (83.798 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1802...
# INFO:tensorflow:Saving checkpoints for 1802 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1802.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1802.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1802.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1802...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1871...
# INFO:tensorflow:Saving checkpoints for 1871 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1871.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1871.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1871.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1871...
# INFO:tensorflow:global_step/sec: 1.06734
# INFO:tensorflow:global_step = 1900, loss = 103.01875 (93.690 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1939...
# INFO:tensorflow:Saving checkpoints for 1939 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1939.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1939.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-1939.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1939...
# INFO:tensorflow:global_step/sec: 1.19943
# INFO:tensorflow:global_step = 2000, loss = 101.42744 (83.373 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2008...
# INFO:tensorflow:Saving checkpoints for 2008 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2008.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2008.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2008.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2008...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2076...
# INFO:tensorflow:Saving checkpoints for 2076 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2076.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2076.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2076.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2076...
# INFO:tensorflow:global_step/sec: 1.06519
# INFO:tensorflow:global_step = 2100, loss = 96.830124 (93.882 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2145...
# INFO:tensorflow:Saving checkpoints for 2145 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2145.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2145.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2145.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2145...
# INFO:tensorflow:global_step/sec: 1.1967
# INFO:tensorflow:global_step = 2200, loss = 95.47309 (83.560 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2213...
# INFO:tensorflow:Saving checkpoints for 2213 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2213.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2213.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2213.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2213...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2284...
# INFO:tensorflow:Saving checkpoints for 2284 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2284.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2284.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2284.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2284...
# INFO:tensorflow:global_step/sec: 1.08544
# INFO:tensorflow:global_step = 2300, loss = 92.86953 (92.128 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2352...
# INFO:tensorflow:Saving checkpoints for 2352 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2352.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2352.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2352.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2352...
# INFO:tensorflow:global_step/sec: 1.18591
# INFO:tensorflow:global_step = 2400, loss = 88.33425 (84.327 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2420...
# INFO:tensorflow:Saving checkpoints for 2420 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2420.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2420.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2420.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2420...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2488...
# INFO:tensorflow:Saving checkpoints for 2488 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2488.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2488.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2488.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2488...
# INFO:tensorflow:global_step/sec: 1.04646
# INFO:tensorflow:global_step = 2500, loss = 88.892204 (95.557 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2555...
# INFO:tensorflow:Saving checkpoints for 2555 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2555.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2555.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2555.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2555...
# INFO:tensorflow:global_step/sec: 1.19322
# INFO:tensorflow:global_step = 2600, loss = 88.560616 (83.807 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2622...
# INFO:tensorflow:Saving checkpoints for 2622 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2622.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2622.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2622.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2622...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2691...
# INFO:tensorflow:Saving checkpoints for 2691 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2691.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2691.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2691.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2691...
# INFO:tensorflow:global_step/sec: 1.07866
# INFO:tensorflow:global_step = 2700, loss = 85.40428 (92.706 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2759...
# INFO:tensorflow:Saving checkpoints for 2759 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2759.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2759.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2759.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2759...
# INFO:tensorflow:global_step/sec: 1.19376
# INFO:tensorflow:global_step = 2800, loss = 86.08166 (83.773 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2828...
# INFO:tensorflow:Saving checkpoints for 2828 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2828.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2828.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2828.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2828...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2897...
# INFO:tensorflow:Saving checkpoints for 2897 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2897.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2897.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2897.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2897...
# INFO:tensorflow:global_step/sec: 1.07875
# INFO:tensorflow:global_step = 2900, loss = 84.01445 (92.704 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2967...
# INFO:tensorflow:Saving checkpoints for 2967 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2967.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2967.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-2967.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2967...
# INFO:tensorflow:global_step/sec: 1.21474
# INFO:tensorflow:global_step = 3000, loss = 83.731964 (82.316 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3035...
# INFO:tensorflow:Saving checkpoints for 3035 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3035.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3035.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3035.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3035...
# INFO:tensorflow:global_step/sec: 1.21803
# INFO:tensorflow:global_step = 3100, loss = 80.649315 (82.102 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3106...
# INFO:tensorflow:Saving checkpoints for 3106 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3106.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3106.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3106.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3106...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3175...
# INFO:tensorflow:Saving checkpoints for 3175 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3175.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3175.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3175.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3175...
# INFO:tensorflow:global_step/sec: 1.07401
# INFO:tensorflow:global_step = 3200, loss = 80.88131 (93.109 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3243...
# INFO:tensorflow:Saving checkpoints for 3243 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3243.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3243.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3243.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3243...
# INFO:tensorflow:global_step/sec: 1.19168
# INFO:tensorflow:global_step = 3300, loss = 76.65936 (83.913 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3311...
# INFO:tensorflow:Saving checkpoints for 3311 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3311.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3311.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3311.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3311...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3380...
# INFO:tensorflow:Saving checkpoints for 3380 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3380.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3380.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3380.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3380...
# INFO:tensorflow:global_step/sec: 1.08105
# INFO:tensorflow:global_step = 3400, loss = 75.58454 (92.503 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3450...
# INFO:tensorflow:Saving checkpoints for 3450 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3450.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3450.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3450.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3450...
# INFO:tensorflow:global_step/sec: 1.18707
# INFO:tensorflow:global_step = 3500, loss = 76.92856 (84.241 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3517...
# INFO:tensorflow:Saving checkpoints for 3517 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3517.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3517.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3517.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3517...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3587...
# INFO:tensorflow:Saving checkpoints for 3587 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3587.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3587.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3587.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3587...
# INFO:tensorflow:global_step/sec: 1.08079
# INFO:tensorflow:global_step = 3600, loss = 76.036415 (92.524 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3655...
# INFO:tensorflow:Saving checkpoints for 3655 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3655.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3655.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3655.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3655...
# INFO:tensorflow:global_step/sec: 1.19859
# INFO:tensorflow:global_step = 3700, loss = 74.89925 (83.435 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3724...
# INFO:tensorflow:Saving checkpoints for 3724 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3724.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3724.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3724.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3724...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3793...
# INFO:tensorflow:Saving checkpoints for 3793 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3793.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3793.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3793.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3793...
# INFO:tensorflow:global_step/sec: 1.07144
# INFO:tensorflow:global_step = 3800, loss = 74.56976 (93.329 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3861...
# INFO:tensorflow:Saving checkpoints for 3861 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3861.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3861.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3861.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3861...
# INFO:tensorflow:global_step/sec: 1.20856
# INFO:tensorflow:global_step = 3900, loss = 72.39238 (82.746 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3930...
# INFO:tensorflow:Saving checkpoints for 3930 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3930.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3930.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3930.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3930...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3997...
# INFO:tensorflow:Saving checkpoints for 3997 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3997.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3997.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-3997.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3997...
# INFO:tensorflow:global_step/sec: 1.03439
# INFO:tensorflow:global_step = 4000, loss = 69.953766 (96.681 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4063...
# INFO:tensorflow:Saving checkpoints for 4063 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4063.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4063.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4063.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4063...
# INFO:tensorflow:global_step/sec: 1.16225
# INFO:tensorflow:global_step = 4100, loss = 69.250175 (86.035 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4128...
# INFO:tensorflow:Saving checkpoints for 4128 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4128.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4128.index
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4128.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4128...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4193...
# INFO:tensorflow:Saving checkpoints for 4193 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4193.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4193.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4193.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4193...
# INFO:tensorflow:global_step/sec: 1.03204
# INFO:tensorflow:global_step = 4200, loss = 69.089264 (96.894 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4261...
# INFO:tensorflow:Saving checkpoints for 4261 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4261.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4261.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4261.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4261...
# INFO:tensorflow:global_step/sec: 1.20864
# INFO:tensorflow:global_step = 4300, loss = 68.28884 (82.737 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4330...
# INFO:tensorflow:Saving checkpoints for 4330 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4330.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4330.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4330.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4330...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4398...
# INFO:tensorflow:Saving checkpoints for 4398 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4398.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4398.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4398.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4398...
# INFO:tensorflow:global_step/sec: 1.06356
# INFO:tensorflow:global_step = 4400, loss = 68.05886 (94.034 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4468...
# INFO:tensorflow:Saving checkpoints for 4468 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4468.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4468.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4468.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4468...
# INFO:tensorflow:global_step/sec: 1.18904
# INFO:tensorflow:global_step = 4500, loss = 66.30753 (84.091 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4535...
# INFO:tensorflow:Saving checkpoints for 4535 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4535.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4535.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4535.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4535...
# INFO:tensorflow:global_step/sec: 1.20672
# INFO:tensorflow:global_step = 4600, loss = 62.670364 (82.871 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4605...
# INFO:tensorflow:Saving checkpoints for 4605 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4605.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4605.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4605.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4605...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4673...
# INFO:tensorflow:Saving checkpoints for 4673 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4673.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4673.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4673.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4673...
# INFO:tensorflow:global_step/sec: 1.06715
# INFO:tensorflow:global_step = 4700, loss = 65.768555 (93.706 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4742...
# INFO:tensorflow:Saving checkpoints for 4742 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4742.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4742.index
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4742.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4742...
# INFO:tensorflow:global_step/sec: 1.20858
# INFO:tensorflow:global_step = 4800, loss = 65.31608 (82.743 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4811...
# INFO:tensorflow:Saving checkpoints for 4811 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4811.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4811.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4811.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4811...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4880...
# INFO:tensorflow:Saving checkpoints for 4880 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4880.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4880.meta
# INFO:tensorflow:43500
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4880.data-00000-of-00001
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4880...
# INFO:tensorflow:global_step/sec: 1.07435
# INFO:tensorflow:global_step = 4900, loss = 64.35553 (93.082 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4949...
# INFO:tensorflow:Saving checkpoints for 4949 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4949.index
# INFO:tensorflow:0
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4949.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-4949.meta
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4949...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into ./model_checkpoint_groovae_4bar_hier_beta/model.ckpt.
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-5000.data-00000-of-00001
# INFO:tensorflow:77400
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-5000.meta
# INFO:tensorflow:120900
# INFO:tensorflow:./model_checkpoint_groovae_4bar_hier_beta/model.ckpt-5000.index
# INFO:tensorflow:120900
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
